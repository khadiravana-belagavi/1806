# %% [markdown]
# <a href="https://colab.research.google.com/github/khadiravana-belagavi/1806/blob/master/Q8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 8
#
# ## Gamma Transforms

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 8.1.
#
# Write a function gammaTransform that implements $s = r^{γ}$ on a grayscale image and vary $\gamma$.

# %%
def gammaTransform(img,gamma):
  width,height = img.shape
  img_min = np.min(img)
  img_max = np.max(img)
  bandwidth = img_max - img_min # Clearly this cannot be zero for this particular image

  new_img = np.zeros((width,height))
  for i in range(width):
    for j in range(height):
      pix = img[i,j]
      new_pix = round(bandwidth*pow((pix/bandwidth),gamma))
      new_img[i,j] = new_pix
  return new_img

# %%
img = cv.imread('/content/drive/My Drive/DIP-Assignment1/assignment-1-khadiravana-belagavi/images/stealth.png')
img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# %%
plt.imshow(img,cmap='gray')

# %%
transformed_img = gammaTransform(img,0.425) #

# %% [markdown]
# ## Question 8.2
# Any Value between 0.4 and 0.5 is good enough for $\gamma$ for illuminating the `stealth.png` image.

# %%
plt.imshow(transformed_img,cmap='gray')

# %%
# plt.imsave('/content/drive/My Drive/DIP-Assignment1/assignment-1-khadiravana-belagavi/images/stealth0425.jpg',transformed_img,cmap='gray')

# %% [markdown]
# ## Question 8.3
# For $2 \leq \gamma \leq 3$ - should suffice to blackout.

# %%
img83 = cv.imread('/content/drive/My Drive/DIP-Assignment1/assignment-1-khadiravana-belagavi/images/unstealth.png')
img83 = cv.cvtColor(img83,cv.COLOR_BGR2GRAY)

# %%
plt.imshow(img83,cmap='gray')

# %%
transformed_img83 = gammaTransform(img83,2.25)
plt.imshow(transformed_img83,cmap='gray')

# %% [markdown]
# ## Question 8.4
#
# Use this function on your Aston Martin DBS image, aston invisible.jpg to see the numberplate clearly so that you can travel to London to report for duty. You will be evaluated on how clear the number plate is after the transformation.

# %%
img_plate = cv.imread('/content/drive/My Drive/DIP-Assignment1/assignment-1-khadiravana-belagavi/images/aston_invisible.jpg')
img_plate = cv.cvtColor(img_plate,cv.COLOR_BGR2GRAY)

# %%
plt.imshow(img_plate,cmap='gray')

# %%
transformed_plate = gammaTransform(img_plate,0.15)
plt.imshow(transformed_plate,cmap='gray')

# %% [markdown]
# For $0.1 \leq \gamma \leq 0.3$ the number plate is clearly visible.
